# %%
import numpy as np
import matplotlib.pyplot as plt
 
with open("/home/adripinto/catkin_ws_user/src/assignment9/src/final_coords.txt") as f:
    content = f.readlines()
content = [x.strip() for x in content]
content = content[1:]
 
for line in content:
    values = line.split(", ")
    plt.scatter(float(values[4]), float(values[5]))
 
plt.show()

# %%
480%360
# Out:
# 120
